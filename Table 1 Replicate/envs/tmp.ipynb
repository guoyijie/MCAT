# %%
import matplotlib.pyplot as plt
from walker2d_env import Walker2dEnv
#env = Walker2dEnv(data_types=['size0.02', 'size0.03', 'size0.04', 'size0.05', 'size0.06'], seed=0)
from hopper_env import HopperEnv
#env = HopperEnv(data_types=['size0.02', 'size0.03', 'size0.04', 'size0.05', 'size0.06'], seed=0)

from inverted_double_pendulum_env import InvertedDoublePendulumEnv
env = InvertedDoublePendulumEnv(data_types=['size0.02', 'size0.03', 'size0.04', 'size0.05', 'size0.06'], seed=0)

# %%
for _ in range(10):
    s = env.reset()
    ob = env.render('rgb_array')
    plt.imshow(ob)
    plt.show()
    print(env.get_sim_parameters())
# Out:
# 0.02
# 0.05
# 0.03
# 0.04
# 0.02
# 0.06
# 0.03
# 0.02
# 0.03
# 0.02
